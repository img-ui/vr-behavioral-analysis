# %%
participant_id = 27
condition = "farmer"
decision_time = 6.2
choice = "save sheep"
embodiment_score = 5.3
conflict_score = 6.6
gaze_switches = 17

print(type(decision_time))
# Out:
# <class 'float'>

# %%
gaze_switch_rate = gaze_switches / decision_time

print(gaze_switch_rate)
# Out:
# 2.7419354838709675

# %%
if conflict_score > 6:
  print("high conflict")
else:
  print("low conflict")
# Out:
# high conflict

# %%
interesting_trial = conflict_score >= 6 and gaze_switches > 15
interesting_trial
# Out:
# True

# %%
print(f"Participant {participant_id} embodied a {condition} and chose to {choice} in {decision_time} seconds.")
# Out:
# Participant 27 embodied a farmer and chose to save sheep in 6.2 seconds.
