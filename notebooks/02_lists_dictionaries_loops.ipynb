# %%
trials = [
    {
        "participant_id": 101,
        "condition": "sheep",
        "decision_time": 3.2,
        "choice": "save_sheep",
        "embodiment_score": 6.1,
        "conflict_score": 4.1,
        "gaze_switches": 9
    },
    {
        "participant_id": 102,
        "condition": "farmer",
        "decision_time": 6.1,
        "choice": "save_farmer",
        "embodiment_score": 5.4,
        "conflict_score": 7.2,
        "gaze_switches": 21
    },
    {
        "participant_id": 103,
        "condition": "sheep",
        "decision_time": 5.4,
        "choice": "save_farmer",
        "embodiment_score": 6.7,
        "conflict_score": 6.3,
        "gaze_switches": 17
    },
    {
        "participant_id": 104,
        "condition": "farmer",
        "decision_time": 2.7,
        "choice": "save_sheep",
        "embodiment_score": 4.9,
        "conflict_score": 3.8,
        "gaze_switches": 6
    }
]

# Print all participant IDs
for trial in trials:
    print(trial["participant_id"])


# Participants with decision times longer than 5 seconds
for trial in trials:
    if trial["decision_time"] > 5:
        print(trial["participant_id"])


# Count participants who saved the sheep
save_sheep_count = 0

for trial in trials:
    if trial["choice"] == "save_sheep":
        save_sheep_count += 1

print(f"Participants who saved the sheep: {save_sheep_count}")


# Count high-conflict trials
high_conflict_count = 0

for trial in trials:
    if trial["conflict_score"] >= 6:
        high_conflict_count += 1

print(f"High-conflict trials: {high_conflict_count}")


# Create an interesting_trial behavioral marker
for trial in trials:
    if trial["conflict_score"] >= 6 and trial["gaze_switches"] > 15:
        trial["interesting_trial"] = True
    else:
        trial["interesting_trial"] = False


# Print interesting trial participant IDs
for trial in trials:
    if trial["interesting_trial"]:
        print(trial["participant_id"])


# Sheep embodiment condition / saved sheep
sheep_condition_save_count = 0

for trial in trials:
    if trial["condition"] == "sheep" and trial["choice"] == "save_sheep":
        sheep_condition_save_count += 1

print(
    f"Participants who saved the sheep after sheep embodiment: "
    f"{sheep_condition_save_count}"
)
# Out:
# 101
# 102
# 103
# 104
# 102
# 103
# 2
# high conflict: 2
# [{'participant_id': 101, 'condition': 'sheep', 'decision_time': 3.2, 'choice': 'save_sheep', 'embodiment_score': 6.1, 'conflict_score': 4.1, 'gaze_switches': 9, 'interesting_trial': False}, {'participant_id': 102, 'condition': 'farmer', 'decision_time': 6.1, 'choice': 'save_farmer', 'embodiment_score': 5.4, 'conflict_score': 7.2, 'gaze_switches': 21, 'interesting_trial': True}, {'participant_id': 103, 'condition': 'sheep', 'decision_time': 5.4, 'choice': 'save_farmer', 'embodiment_score': 6.7, 'conflict_score': 6.3, 'gaze_switches': 17, 'interesting_trial': True}, {'participant_id': 104, 'condition': 'farmer', 'decision_time': 2.7, 'choice': 'save_sheep', 'embodiment_score': 4.9, 'conflict_score': 3.8, 'gaze_switches': 6, 'interesting_trial': False}]
# 102
# 103
# The number of people who saved the sheep after the sheep condition: 1

# %% [markdown]
# # Day 2 — Lists, Dictionaries, and Loops
#
# This notebook practices core Python concepts using a synthetic XR moral decision-making dataset.
#
# Topics covered:
# - Lists
# - Dictionaries
# - For loops
# - Conditional filtering
# - Counting observations
# - Creating derived behavioral variables
#
# The examples are based on a hypothetical experiment involving sheep and farmer embodiment conditions followed by a moral decision-making task.
