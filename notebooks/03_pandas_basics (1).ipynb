# %% [markdown]
# # Day 3 — Pandas Basics
#
# This notebook introduces Pandas using a synthetic XR moral decision-making dataset.
#
# Topics covered:
# - Creating a DataFrame
# - Inspecting data
# - Selecting columns
# - Filtering rows
# - Creating derived variables
# - Basic descriptive statistics
# - Frequency counts

# %%
# !ls /content
# Out:
# sample_data  vr_moral_dilemma_day3.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/vr_moral_dilemma_day3.csv")

# %%
df
# Out:
#    participant_id condition  decision_time       choice  embodiment_score  \
# 0             101     sheep            3.2   save_sheep               6.1
# 1             102    farmer            6.1  save_farmer               5.4
# 2             103     sheep            5.4  save_farmer               6.7
# 3             104    farmer            2.7   save_sheep               4.9
#
#    conflict_score  gaze_switches
# 0             4.1              9
# 1             7.2             21
# 2             6.3             17
# 3             3.8              6

# %%
# number of columns and rows
df.shape
# Out:
# (4, 7)

# %%
df[["participant_id","condition","choice"]]
# Out:
#    participant_id condition       choice
# 0             101     sheep   save_sheep
# 1             102    farmer  save_farmer
# 2             103     sheep  save_farmer
# 3             104    farmer   save_sheep

# %%
df[df["decision_time"] > 4]
# Out:
#    participant_id condition  decision_time       choice  embodiment_score  \
# 1             102    farmer            6.1  save_farmer               5.4
# 2             103     sheep            5.4  save_farmer               6.7
#
#    conflict_score  gaze_switches
# 1             7.2             21
# 2             6.3             17

# %%
df[df["condition"] == "farmer"]
# Out:
#    participant_id condition  decision_time       choice  embodiment_score  \
# 1             102    farmer            6.1  save_farmer               5.4
# 3             104    farmer            2.7   save_sheep               4.9
#
#    conflict_score  gaze_switches
# 1             7.2             21
# 3             3.8              6

# %%
# creating a new column: interesting trial
df["interesting_trial"] = ((df["embodiment_score"] > 6) & (df["conflict_score"] < 3))

# %%
df["decision_time"].mean()
# Out:
# np.float64(4.3500000000000005)

# %%
df["embodiment_score"].median()
# Out:
# 5.75

# %%
df["choice"].value_counts()
# Out:
# choice
# save_sheep     2
# save_farmer    2
# Name: count, dtype: int64

# %%
df["condition"].value_counts()
# Out:
# condition
# sheep     2
# farmer    2
# Name: count, dtype: int64

# %%
# Average decision time in sheep condition

sheep_df = df[df["condition"] == "sheep"]

sheep_df["decision_time"].mean()
# Out:
# np.float64(4.300000000000001)
